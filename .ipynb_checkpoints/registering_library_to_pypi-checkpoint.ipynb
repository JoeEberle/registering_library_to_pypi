# %% [markdown]
# ![registering_library_to_pypi.png](attachment:d47592f4-3662-48b2-aa45-a3c6fdf244f8.png)

# %% [markdown]
# ## 🧠 Registering library to pypi
# The **registering_library_to_pypi** is designed to modularize and accelerate the development of AI-driven solutions.
#
#
# # 🧩 Registering Libraries
#
# > Created by **ThriveAI  ...      Joe Eberle**
# > 🗓️ Started: April 18, 2025
# > 📫 Contact: [josepheberle@outlook.com](mailto:josepheberle@outlook.com)
# > 🔗 GitHub: [JoeEberle](https://github.com/JoeEberle/)

# %%
first_time_run = False
if first_time_run:
    # !pip install build
    # !pip install twine

# %%
import os
import schedule
from datetime import datetime
import pandas as pd 
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import story_board as sb 
import registering_library as rl 
import time
from pathlib import Path
from IPython.display import Markdown, display, Image
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2025-05-03 at 12:22:49.374102

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'registering_library_to_pypi'

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process registering_library_to_pypi Step 0 - Initializing and starting Logging Process.

# %%
definition ='''
## 🧠 Registering library to pypi
The **registering_library_to_pypi** is designed to modularize and accelerate the development of AI driven solutions. 

'''

sb.start_story(definition)
# Out:
# ## 🧠 Registering library to pypi
# The **registering_library_to_pypi** is designed to modularize and accelerate the development of AI-driven solutions.

# %%
definition ='''
# 🧩 Registering Libraries

#### A modular, AI first solution scaffold  

> Created by **ThriveAI  ...      Joe Eberle**  
> 🗓️ Started: April 18, 2025 
> 📫 Contact: [josepheberle@outlook.com](mailto:josepheberle@outlook.com)  
> 🔗 GitHub: [JoeEberle](https://github.com/JoeEberle/)

'''

sb.outmd(definition)
# Out:
# # 🧩 Registering Libraries
#
# #### A modular, AI first solution scaffold
#
# > Created by **ThriveAI  ...      Joe Eberle**
# > 🗓️ Started: April 18, 2025
# > 📫 Contact: [josepheberle@outlook.com](mailto:josepheberle@outlook.com)
# > 🔗 GitHub: [JoeEberle](https://github.com/JoeEberle/)

# %% [markdown]
# ## Step 1 - Create project directory

# %%
library_name = 'registering_library'
register = rl.create_project_directory(library_name)
# Out:
# ✅ Successfully created or found existing directory: C:\Users\josep\registering_library_to_pypi\registering_library

# %% [markdown]
# ## Step 2 - Create toml file

# %%
toml = rl.create_pyproject_toml_file(library_name)
# Out:
# ✅ pyproject.toml created at: C:\Users\josep\registering_library_to_pypi\registering_library\pyproject.toml

# %% [markdown]
# ## Step 3 - Create  setup py file

# %%
library_name = 'registering_library'
modules = ['pathlib']
version_number = '0.1.0'
author_name='Joe Eberle'
auth_email = 'josepheberle@outlook.com'
library_description = "library of functions to register libraries to PyPi" 

toml = rl.create_setup_py_file(library_name, modules, version_number, auth_email, library_description)
# Out:
# ✅ setup.py created at: C:\Users\josep\registering_library_to_pypi\registering_library\setup.py

# %% [markdown]
# ## Step 4 - publish to pypi generic

# %%
publish = rl.publish_to_pypi_generic(publish_to_pypi_generic(
    library_name,
    library_description,
    library_version,
    library_dependencies=None,
    author_name='Your Name',
    author_email='you@example.com',
    github_url='https://github.com/your_username/your_repo'
)

# %%
import os
import subprocess
from pathlib import Path

def publish_to_pypi_generic(
    library_name,
    library_description,
    library_version,
    library_dependencies=None,
    author_name='Your Name',
    author_email='you@example.com',
    github_url='https://github.com/your_username/your_repo'
):
    """
    Package and publish a single-file Python library to PyPI.
    Assumes the file library_name.py exists in the current directory.
    """
    print(f"📦 Packaging library: {library_name}")

    # Install build tools
    subprocess.run(["pip", "install", "--upgrade", "build"], check=True)
    subprocess.run(["python", "-m", "build"], cwd=library_dir, check=True)

    # Upload to PyPI
    subprocess.run(["pip", "install", "--upgrade", "twine"], check=True)
    print("📤 Uploading to PyPI — you will be prompted for credentials.")
    subprocess.run(["twine", "upload", "dist/*"], cwd=library_dir, check=True)

    print(f"✅ Library '{library_name}' version {library_version} published to PyPI.")

# %%
# !where python
# Out:
# C:\Users\josep\anaconda3\python.exe
# C:\Users\josep\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# C:\Users\josep\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !python --version
# Out:
# Python 3.12.7

# %%
publish_to_pypi_generic(
    library_name='ethical_guardrails',
    library_description='A toolkit for enforcing ethical AI and chatbot behavior.',
    library_version='0.1.0',
    library_dependencies=['openai', 'pandas'],
    author_name='Joe Eberle',
    author_email='joe@example.com',
    github_url='https://github.com/JoeEberle/ethical_guardrails'
)

# %%
Password
y9pSdcUv.xmuV-U


Site
https://pypi.org/account/register/

Notes

# %%
publish_to_pypi_generic(
    library_name='domain_topic_classifier',
    library_description='A toolkit for enforcing classifying doamins and topics based upon keywords.',
    library_version='0.1.0',
    library_dependencies=['re', 'rapidfuzz'],
    author_name='Joe Eberle',
    author_email='joe@example.com',
    github_url='https://github.com/JoeEberle/domain_topic_classifier'
)

# %%
def create_README_MD_file(library_name):
    return 0

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
